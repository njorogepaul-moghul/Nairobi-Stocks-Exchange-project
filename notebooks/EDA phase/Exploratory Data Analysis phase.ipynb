# %% [markdown]
# ## Exploratory Data Analysis Phase

# %%
# we import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scom=pd.read_csv(r"C:\Users\Win\NSE Project\Data\2013 to 2024 CLEANED_cosolidated_SAFARICOM_stocks nse_data.csv")
scom.head()
# Out:
#          DATE  CODE           NAME  12m Low  12m High  Day Low  Day High  \
# 0  2013-01-02  SCOM  Safaricom Plc     23.5      33.5     5.00      5.15
# 1  2013-01-03  SCOM  Safaricom Plc     23.5      33.5     5.10      5.25
# 2  2013-01-04  SCOM  Safaricom Plc     23.5      33.5     5.15      5.35
# 3  2013-01-07  SCOM  Safaricom Plc     23.5      33.5     5.20      5.45
# 4  2013-01-08  SCOM  Safaricom Plc     23.5      33.5     5.40      5.85
#
#    Day Price  Previous  Change   Change%      Volume
# 0       5.10      5.00    0.10  0.000200   3320600.0
# 1       5.15      5.10    0.05  0.000098   7252500.0
# 2       5.25      5.15    0.10  0.000194   4125900.0
# 3       5.35      5.25    0.10  0.000190   4098600.0
# 4       5.60      5.35    0.25  0.000467  10998900.0
